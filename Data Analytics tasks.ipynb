# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df_sk = df.copy()
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df["Time"] = df["Time"].apply(lambda x: 1 if x=="0" else 0)
 
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
dum = pd.get_dummies(df.Time,drop_first=True)

# %%
df = pd.concat([dum,df],axis = 1)

# %%
df
# Out:
#         Time         V1         V2        V3        V4        V5        V6  \
# 0          0  -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0   1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          0  -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          0  -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...        ...        ...       ...       ...       ...       ...
# 284802     0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803     0  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804     0   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805     0  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806     0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
# ...

# %%
std=StandardScaler()
columns = ['V1','V2']
scaled = std.fit_transform(df[['V1','V2']])
scaled = pd.DataFrame(scaled,columns=columns)
df=df.drop(columns=columns,axis=1)
df=df.merge(scaled, left_index=True, right_index=True, how = "left")
df.head()
# Out:
#    Time        V3        V4        V5        V6        V7        V8        V9  \
# 0     0  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787
# 1     0  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425
# 2     0  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654
# 3     0  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024
# 4     0  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739
#
#         V10       V11  ...       V23       V24       V25       V26       V27  \
# 0  0.090794 -0.551600  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1 -0.166974  1.612727  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.207643  0.624501  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3 -0.054952 -0.226487  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4  0.753074 -0.822843  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %%
df_sk.V1.hist()

# %%
skew(df_sk.V1)
# Out:
# -3.2806500243599563

# %%
from scipy import stats
Boxcox_Val = df_sk.V1.map(lambda i: np.abs(i) if i < 0 else (i+1 if i==0 else i))
Boxcox_Val= stats.boxcox(Boxcox_Val)
Boxcox_Val= pd.Series(Boxcox_Val[0])
t=sns.distplot(Boxcox_Val,label="Skewness: %.2f"%(Boxcox_Val.skew()) )
Boxcox_Val.skew()
# Out:
# 0.1882296366554088

# %%
df_sk.avg_V2.hist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-2d4563d857dc> in <module>
# ----> 1 df_sk.avg_V2.hist()
#
# ~\Anaconda3\envs\myenv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'avg_V2'

# %%
df_sk.Time.hist()

# %%
skew(df_sk.Time)
# Out:
# -0.03556743068120296

# %%
from scipy import stats
Boxcox_Val = df_sk.Time.map(lambda i: np.abs(i) if i < 0 else (i+1 if i==0 else i))
Boxcox_Val= stats.boxcox(Boxcox_Val)
Boxcox_Val= pd.Series(Boxcox_Val[0])
t=sns.distplot(Boxcox_Val,label="Skewness: %.2f"%(Boxcox_Val.skew()) )
Boxcox_Val.skew()
# Out:
# -0.22975605587727382

# %%
beta0 = 3.0 # intercept
beta1 = -1 # slope
n = 500
x1_true = np.random.normal(5, 3, n)
x2_true = np.zeros(n)

# generate a random sample
for i in range(n):
    x2_true[i] = beta0 + beta1*x1_true[i] + np.random.normal(size = 1)
    
# generate outliers
x1_outliers = np.random.uniform(-4, -2, 6)
x2_outliers = np.zeros(6)
for i in range(6):
    x2_outliers[i] = x1_outliers[i] + np.random.normal(size = 1)

plt.scatter(x1_true, x2_true)
plt.plot(x1_outliers, x2_outliers, 'ro', markersize=8)

# %%
from sklearn.preprocessing import scale
x1 = scale(np.concatenate([x1_true, x1_outliers]))
x2 = scale(np.concatenate([x2_true, x2_outliers]))

#spatial sign
dist = x1**2 + x2**2
x1 = x1/np.sqrt(dist)
x2 = x2/np.sqrt(dist)

plt.scatter(x1, x2)
plt.plot(x1[-6:], x2[-6:], 'ro', markersize=10)
